# %%
import geopandas as gpd

# %%
gdf=gpd.read_file("/home/alex/Downloads/oria_dhmwn_kallikraths/oria_dhmwn_kallikraths.shp",encoding="UTF8")
# Out:
# /home/alex/.local/lib/python3.10/site-packages/pyogrio/raw.py:196: RuntimeWarning: One or several characters couldn't be converted correctly from UTF8 to UTF-8.  This warning will not be emitted anymore
#   return ogr_read(

# %%
print(gdf)
# Out:
#     NAME KWD_YPES                                           geometry
# 0            9070  POLYGON ((306603.594 4524540, 306778.813 45244...
# 1            None  MULTIPOLYGON (((521237.594 4461202, 521222.406...
# 2     -      9124  MULTIPOLYGON (((221292.406 4294039, 221292.203...
# 3            9268  MULTIPOLYGON (((584417.125 4171609, 584399.313...
# 4     -      9233  POLYGON ((369695.313 4188647, 369719.312 41886...
# ..   ...      ...                                                ...
# 321          9267  MULTIPOLYGON (((629706.812 4265487, 629682.125...
# 322          9039  MULTIPOLYGON (((399013.187 4506369, 399465.906...
# 323          9227  POLYGON ((476342.812 4242735, 476352.906 42427...
# 324          9286  MULTIPOLYGON (((557462.687 4066104, 557442.625...
# 325          9301  MULTIPOLYGON (((590687 4163329, 590698.5 41633...
#
# [326 rows x 3 columns]

# %%
gdf.plot(column="KWD_YPES",figsize=(20, 15))
# Out:
# <Axes: >
